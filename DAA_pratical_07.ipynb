# %% [markdown]
# <a href="https://colab.research.google.com/github/srinivasaraoyarramreddy127517-ops/DAA-LABS/blob/main/DAA_pratical_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Coin Change Problem using Dynamic Programming

def coin_change(coins, amount):

    dp = [float('inf')] * (amount + 1)
    dp[0] = 0

    for i in range(1, amount + 1):
        for coin in coins:
            if coin <= i:
                dp[i] = min(dp[i], dp[i - coin] + 1)

    return dp[amount]

# Input
coins = list(map(int, input("Enter coin values: ").split()))
amount = int(input("Enter amount: "))

# Output
print("Minimum coins required:", coin_change(coins, amount))
# Out:
# Enter coin values: 1 3 5 7
# Enter amount: 10
# Minimum coins required: 2
